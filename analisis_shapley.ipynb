# %% [markdown]
# # Análisis de Valores de Shapley
#
# Análisis de Shapley values para medir la contribución relativa de las variables de comportamiento al poder predictivo del modelo GAM

# %%
# %load_ext autoreload
# %autoreload 2

import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append(os.path.abspath('.'))

from scripts.utils.data_loader import (
    preparar_datos_posicion,
    preparar_datos_head_direction,
    preparar_datos_mirada,
)
from scripts.utils.cross_validation import generate_all_splits
from scripts.utils.shapley_values import train_and_evaluate_shapley_subsets, calculate_shapley_values, plot_shapley_values

# %%
sesion = 2
tetrodo = 3
neurona = 1
bin_size_sec = 0.1

# %%
# Cargar dato de head direction
ang_bins_deg, spikes_hd = preparar_datos_head_direction(sesion, tetrodo, neurona, bin_size_sec=bin_size_sec)
hd_rad = np.radians(ang_bins_deg)

# Cargar datos de posición y mirada
x_bins, y_bins, ang_bins_rad, spikes_gaze = preparar_datos_mirada(
    sesion, tetrodo, neurona, bin_size_sec=bin_size_sec
)

# Punto de interés óptimo (usamos uno precalculado como ejemplo)
x_best_p, y_best_p = 17.7, -5.2
distances = np.sqrt((x_bins - x_best_p)**2 + (y_bins - y_best_p)**2)

# Viewpoint: ángulo relativo hacia el punto de interés
dy = y_best_p - y_bins
dx = x_best_p - x_bins
ang_hacia_punto = np.arctan2(dy, dx)
theta_corrected = np.mod(ang_bins_rad - ang_hacia_punto, 2 * np.pi)

# Crear matriz X de tamaño (N, 5)
# Columnas: 0=Posición X, 1=Posición Y, 2=Head Direction (rad), 3=Viewpoint (rad), 4=Distancia
X_shapley = np.column_stack((x_bins, y_bins, hd_rad, theta_corrected, distances))
Y_shapley = spikes_gaze

print(f"Total de muestras: {len(X_shapley)}")

# particion de datos
folds, held_out_idx, train_pool_idx, roles = generate_all_splits(
    n_muestras=len(X_shapley),
    bin_size_sec=bin_size_sec,
    block_size_sec=60,
    n_folds=5,
    buffer_sec=2
)

X_pool, Y_pool = X_shapley[train_pool_idx], Y_shapley[train_pool_idx]
X_held, Y_held = X_shapley[held_out_idx], Y_shapley[held_out_idx]
# Out:
# Total de muestras: 11952

# %%
# Lista de variables a evaluar con Shapley
features = ['pos', 'hd', 'view', 'dist']

# Entrenamos todos los subconjuntos (2^N - 1 = 15 modelos para 4 variables)
metrics = train_and_evaluate_shapley_subsets(
    X_shapley, Y_shapley, folds, X_pool, Y_pool, X_held, Y_held,
    splines_grid=[9], lambdas_grid=np.logspace(-1, 1, 7), features=features
)
# Out:
# ========================================
# Evaluando sub-modelo: shapley_pos
# ========================================
# sp= 9, lam= 0.1000000 | edof:  23.6256 | nll test: 0.37139741 (± 0.06060291)
# sp= 9, lam= 0.2154435 | edof:  19.9815 | nll test: 0.36802827 (± 0.06065080)
# sp= 9, lam= 0.4641589 | edof:  16.7499 | nll test: 0.36627701 (± 0.06133269)
# sp= 9, lam= 1.0000000 | edof:  13.9427 | nll test: 0.36632597 (± 0.06245835)
# sp= 9, lam= 2.1544347 | edof:  11.5295 | nll test: 0.36754516 (± 0.06355663)
# sp= 9, lam= 4.6415888 | edof:   9.4828 | nll test: 0.36869292 (± 0.06423474)
# sp= 9, lam=10.0000000 | edof:   7.8027 | nll test: 0.36899230 (± 0.06453518)
# [*] Pseudo R² (McFadden) para shapley_pos: 0.161909
#
# ========================================
# Evaluando sub-modelo: shapley_hd
# ========================================
# sp= 9, lam= 0.1000000 | edof:   8.4264 | nll test: 0.39309379 (± 0.07191562)
# sp= 9, lam= 0.2154435 | edof:   8.0564 | nll test: 0.39275128 (± 0.07168395)
# sp= 9, lam= 0.4641589 | edof:   7.6066 | nll test: 0.39227272 (± 0.07138426)
# sp= 9, lam= 1.0000000 | edof:   7.1319 | nll test: 0.39155021 (± 0.07099709)
# sp= 9, lam= 2.1544347 | edof:   6.6696 | nll test: 0.39060259 (± 0.07054854)
# sp= 9, lam= 4.6415888 | edof:   6.2316 | nll test: 0.38958754 (± 0.07010706)
# sp= 9, lam=10.0000000 | edof:   5.8126 | nll test: 0.38862698 (± 0.06971504)
# [*] Pseudo R² (McFadden) para shapley_hd: 0.002423
#
# ========================================
# Evaluando sub-modelo: shapley_view
# ========================================
# sp= 9, lam= 0.1000000 | edof:   8.2847 | nll test: 0.38576131 (± 0.06851641)
# sp= 9, lam= 0.2154435 | edof:   7.8468 | nll test: 0.38520232 (± 0.06824157)
# sp= 9, lam= 0.4641589 | edof:   7.3446 | nll test: 0.38472199 (± 0.06799080)
# sp= 9, lam= 1.0000000 | edof:   6.8428 | nll test: 0.38432335 (± 0.06779114)
# sp= 9, lam= 2.1544347 | edof:   6.3703 | nll test: 0.38395580 (± 0.06764642)
# sp= 9, lam= 4.6415888 | edof:   5.9272 | nll test: 0.38358225 (± 0.06755527)
# sp= 9, lam=10.0000000 | edof:   5.5032 | nll test: 0.38317133 (± 0.06751231)
# [*] Pseudo R² (McFadden) para shapley_view: 0.041942
#
# ========================================
# Evaluando sub-modelo: shapley_dist
# ========================================
# sp= 9, lam= 0.1000000 | edof:   6.9227 | nll test: 0.38096092 (± 0.07120631)
# sp= 9, lam= 0.2154435 | edof:   6.4818 | nll test: 0.38077193 (± 0.07104169)
# sp= 9, lam= 0.4641589 | edof:   6.0066 | nll test: 0.38056465 (± 0.07093713)
# sp= 9, lam= 1.0000000 | edof:   5.4993 | nll test: 0.38045850 (± 0.07097209)
# sp= 9, lam= 2.1544347 | edof:   4.9748 | nll test: 0.38063568 (± 0.07121953)
# sp= 9, lam= 4.6415888 | edof:   4.4608 | nll test: 0.38133025 (± 0.07171457)
# sp= 9, lam=10.0000000 | edof:   3.9800 | nll test: 0.38273784 (± 0.07241120)
# [*] Pseudo R² (McFadden) para shapley_dist: 0.096655
#
# ========================================
# Evaluando sub-modelo: shapley_pos_hd
# ========================================
# sp= 9, lam= 0.1000000 | edof:  30.9570 | nll test: 0.37928366 (± 0.06402721)
# sp= 9, lam= 0.2154435 | edof:  26.9539 | nll test: 0.37601940 (± 0.06396666)
# sp= 9, lam= 0.4641589 | edof:  23.2825 | nll test: 0.37411169 (± 0.06435980)
# sp= 9, lam= 1.0000000 | edof:  20.0087 | nll test: 0.37346041 (± 0.06497218)
# sp= 9, lam= 2.1544347 | edof:  17.1428 | nll test: 0.37336664 (± 0.06534683)
# sp= 9, lam= 4.6415888 | edof:  14.6688 | nll test: 0.37287936 (± 0.06521563)
# sp= 9, lam=10.0000000 | edof:  12.5781 | nll test: 0.37162994 (± 0.06477126)
# [*] Pseudo R² (McFadden) para shapley_pos_hd: 0.160137
#
# ========================================
# Evaluando sub-modelo: shapley_pos_view
# ========================================
# sp= 9, lam= 0.1000000 | edof:  30.8937 | nll test: 0.36118409 (± 0.05621985)
# sp= 9, lam= 0.2154435 | edof:  26.8284 | nll test: 0.35822750 (± 0.05606293)
# sp= 9, lam= 0.4641589 | edof:  23.1061 | nll test: 0.35679545 (± 0.05672553)
# sp= 9, lam= 1.0000000 | edof:  19.8100 | nll test: 0.35717181 (± 0.05805690)
# sp= 9, lam= 2.1544347 | edof:  16.9384 | nll test: 0.35890078 (± 0.05952751)
# sp= 9, lam= 4.6415888 | edof:  14.4580 | nll test: 0.36075288 (± 0.06059940)
# sp= 9, lam=10.0000000 | edof:  12.3566 | nll test: 0.36178562 (± 0.06122752)
# [*] Pseudo R² (McFadden) para shapley_pos_view: 0.222512
#
# ========================================
# Evaluando sub-modelo: shapley_pos_dist
# ========================================
# sp= 9, lam= 0.1000000 | edof:  25.7935 | nll test: 0.36835528 (± 0.05854963)
# sp= 9, lam= 0.2154435 | edof:  22.0071 | nll test: 0.36304053 (± 0.05778876)
# sp= 9, lam= 0.4641589 | edof:  18.6534 | nll test: 0.35884360 (± 0.05753642)
# sp= 9, lam= 1.0000000 | edof:  15.7247 | nll test: 0.35635432 (± 0.05803649)
# sp= 9, lam= 2.1544347 | edof:  13.1870 | nll test: 0.35606237 (± 0.05930837)
# sp= 9, lam= 4.6415888 | edof:  11.0226 | nll test: 0.35779181 (± 0.06104595)
# sp= 9, lam=10.0000000 | edof:   9.2466 | nll test: 0.36049605 (± 0.06272818)
# [*] Pseudo R² (McFadden) para shapley_pos_dist: 0.206304
#
# ========================================
# Evaluando sub-modelo: shapley_hd_view
# ========================================
# sp= 9, lam= 0.1000000 | edof:  15.6989 | nll test: 0.39385152 (± 0.07209260)
# sp= 9, lam= 0.2154435 | edof:  14.8883 | nll test: 0.39305029 (± 0.07164296)
# sp= 9, lam= 0.4641589 | edof:  13.9363 | nll test: 0.39213778 (± 0.07111161)
# sp= 9, lam= 1.0000000 | edof:  12.9608 | nll test: 0.39100345 (± 0.07050578)
# sp= 9, lam= 2.1544347 | edof:  12.0255 | nll test: 0.38963937 (± 0.06986657)
# sp= 9, lam= 4.6415888 | edof:  11.1407 | nll test: 0.38817328 (± 0.06926765)
# sp= 9, lam=10.0000000 | edof:  10.2911 | nll test: 0.38669948 (± 0.06875373)
# [*] Pseudo R² (McFadden) para shapley_hd_view: 0.048427
#
# ========================================
# Evaluando sub-modelo: shapley_hd_dist
# ========================================
# sp= 9, lam= 0.1000000 | edof:  14.3308 | nll test: 0.38854438 (± 0.07375026)
# sp= 9, lam= 0.2154435 | edof:  13.5230 | nll test: 0.38784948 (± 0.07345568)
# sp= 9, lam= 0.4641589 | edof:  12.6000 | nll test: 0.38715742 (± 0.07314383)
# sp= 9, lam= 1.0000000 | edof:  11.6190 | nll test: 0.38633540 (± 0.07285984)
# sp= 9, lam= 2.1544347 | edof:  10.6340 | nll test: 0.38547003 (± 0.07269942)
# sp= 9, lam= 4.6415888 | edof:   9.6846 | nll test: 0.38493505 (± 0.07277218)
# sp= 9, lam=10.0000000 | edof:   8.7884 | nll test: 0.38510669 (± 0.07308482)
# [*] Pseudo R² (McFadden) para shapley_hd_dist: 0.095217
#
# ========================================
# Evaluando sub-modelo: shapley_view_dist
# ========================================
# sp= 9, lam= 0.1000000 | edof:  14.1705 | nll test: 0.37680112 (± 0.07175409)
# sp= 9, lam= 0.2154435 | edof:  13.2974 | nll test: 0.37575734 (± 0.07121327)
# sp= 9, lam= 0.4641589 | edof:  12.3277 | nll test: 0.37476714 (± 0.07071607)
# sp= 9, lam= 1.0000000 | edof:  11.3276 | nll test: 0.37388723 (± 0.07032106)
# sp= 9, lam= 2.1544347 | edof:  10.3422 | nll test: 0.37322456 (± 0.07010015)
# sp= 9, lam= 4.6415888 | edof:   9.3984 | nll test: 0.37306918 (± 0.07017690)
# sp= 9, lam=10.0000000 | edof:   8.5043 | nll test: 0.37378200 (± 0.07063885)
# [*] Pseudo R² (McFadden) para shapley_view_dist: 0.155358
#
# ========================================
# Evaluando sub-modelo: shapley_pos_hd_view
# ========================================
# sp= 9, lam= 0.1000000 | edof:  38.1609 | nll test: 0.36828440 (± 0.05890536)
# sp= 9, lam= 0.2154435 | edof:  33.7277 | nll test: 0.36505724 (± 0.05879978)
# sp= 9, lam= 0.4641589 | edof:  29.5674 | nll test: 0.36294289 (± 0.05934779)
# sp= 9, lam= 1.0000000 | edof:  25.8067 | nll test: 0.36224072 (± 0.06037228)
# sp= 9, lam= 2.1544347 | edof:  22.4758 | nll test: 0.36270520 (± 0.06140430)
# sp= 9, lam= 4.6415888 | edof:  19.5535 | nll test: 0.36337883 (± 0.06199359)
# sp= 9, lam=10.0000000 | edof:  17.0248 | nll test: 0.36347279 (± 0.06212562)
# [*] Pseudo R² (McFadden) para shapley_pos_hd_view: 0.236641
#
# ========================================
# Evaluando sub-modelo: shapley_pos_hd_dist
# ========================================
# sp= 9, lam= 0.1000000 | edof:  33.1091 | nll test: 0.37715172 (± 0.06216620)
# sp= 9, lam= 0.2154435 | edof:  28.9620 | nll test: 0.37161346 (± 0.06119636)
# sp= 9, lam= 0.4641589 | edof:  25.1676 | nll test: 0.36707739 (± 0.06063616)
# sp= 9, lam= 1.0000000 | edof:  21.7712 | nll test: 0.36388251 (± 0.06068627)
# sp= 9, lam= 2.1544347 | edof:  18.7817 | nll test: 0.36231300 (± 0.06134783)
# sp= 9, lam= 4.6415888 | edof:  16.1960 | nll test: 0.36230829 (± 0.06237795)
# sp= 9, lam=10.0000000 | edof:  14.0173 | nll test: 0.36317349 (± 0.06336377)
# [*] Pseudo R² (McFadden) para shapley_pos_hd_dist: 0.200341
#
# ========================================
# Evaluando sub-modelo: shapley_pos_view_dist
# ========================================
# sp= 9, lam= 0.1000000 | edof:  32.9619 | nll test: 0.35895649 (± 0.05509206)
# sp= 9, lam= 0.2154435 | edof:  28.7516 | nll test: 0.35337863 (± 0.05412323)
# sp= 9, lam= 0.4641589 | edof:  24.9148 | nll test: 0.34882114 (± 0.05379755)
# sp= 9, lam= 1.0000000 | edof:  21.5056 | nll test: 0.34596999 (± 0.05428880)
# sp= 9, lam= 2.1544347 | edof:  18.5219 | nll test: 0.34543699 (± 0.05559094)
# sp= 9, lam= 4.6415888 | edof:  15.9438 | nll test: 0.34715763 (± 0.05746223)
# sp= 9, lam=10.0000000 | edof:  13.7619 | nll test: 0.35010297 (± 0.05946437)
# [*] Pseudo R² (McFadden) para shapley_pos_view_dist: 0.269541
#
# ========================================
# Evaluando sub-modelo: shapley_hd_view_dist
# ========================================
# sp= 9, lam= 0.1000000 | edof:  21.5728 | nll test: 0.38361280 (± 0.07364528)
# sp= 9, lam= 0.2154435 | edof:  20.3300 | nll test: 0.38266166 (± 0.07303692)
# sp= 9, lam= 0.4641589 | edof:  18.9115 | nll test: 0.38165074 (± 0.07240008)
# sp= 9, lam= 1.0000000 | edof:  17.4365 | nll test: 0.38040910 (± 0.07177342)
# sp= 9, lam= 2.1544347 | edof:  15.9862 | nll test: 0.37902611 (± 0.07127678)
# sp= 9, lam= 4.6415888 | edof:  14.5991 | nll test: 0.37796061 (± 0.07110800)
# sp= 9, lam=10.0000000 | edof:  13.2804 | nll test: 0.37772010 (± 0.07137847)
# [*] Pseudo R² (McFadden) para shapley_hd_view_dist: 0.162930
#
# ========================================
# Evaluando sub-modelo: shapley_pos_hd_view_dist
# ========================================
# sp= 9, lam= 0.1000000 | edof:  40.2175 | nll test: 0.36567421 (± 0.05754896)
# sp= 9, lam= 0.2154435 | edof:  35.6342 | nll test: 0.35966864 (± 0.05649745)
# sp= 9, lam= 0.4641589 | edof:  31.3571 | nll test: 0.35439471 (± 0.05598554)
# sp= 9, lam= 1.0000000 | edof:  27.4847 | nll test: 0.35053062 (± 0.05617586)
# sp= 9, lam= 2.1544347 | edof:  24.0477 | nll test: 0.34878709 (± 0.05708990)
# sp= 9, lam= 4.6415888 | edof:  21.0350 | nll test: 0.34925563 (± 0.05853554)
# sp= 9, lam=10.0000000 | edof:  18.4320 | nll test: 0.35101120 (± 0.06009654)
# [*] Pseudo R² (McFadden) para shapley_pos_hd_view_dist: 0.280663

# %%
# Calcular contribuciones Shapley
phi = calculate_shapley_values(metrics, features=features)

# plot
total_r2 = metrics['shapley_' + '_'.join(features)] - metrics['null']
plot_shapley_values(phi, total_r2=total_r2)
